# %% [markdown]
# ### KLT Tracking
#
# 光流数学原理 参考：
#
#   （1）https://zhuanlan.zhihu.com/p/88033287
#
#   （2）https://zhuanlan.zhihu.com/p/620190584
#
# python 实现参考：https://github.com/ZheyuanXie/KLT-Feature-Tracking
#
# C++ 实现参考: https://github.com/qiaozhijian/KLT-Optical-Flow
